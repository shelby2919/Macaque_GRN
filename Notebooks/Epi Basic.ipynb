# %%
directory="."
netPath="Epi"
netTitle="Epithelial GRN"
networkFile='prior_lung_epithelial_macaque_b_bias50_maxComb_sp_10meanEdgesPerGene.tsv'
expressionFile="scrna_pseudobulk_Epithelial_Log2TPM.txt"
rnaSampleOfInt='AT1_AT2_Ctrl' #Choose condition to compare other samples to for heatmap
tfsPerGene=10

# %%
import sys
import os.path
if ".." not in sys.path:
    sys.path.append("..")
from jp_gene_viz import dNetwork
dNetwork.load_javascript_support()
# from jp_gene_viz import multiple_network
from jp_gene_viz import LExpression
LExpression.load_javascript_support()

# %%
###Build object to inspect GRN graphically
N=dNetwork.display_network(directory+'/'+netPath+'/'+networkFile)
N.title_html.value = netTitle
# Out:
# ('Reading network', './Epi/prior_lung_epithelial_macaque_b_bias50_maxComb_sp_10meanEdgesPerGene.tsv')
# Computing layout
# Using fast layout because the network is large.
# ('Saving layout', './Epi/prior_lung_epithelial_macaque_b_bias50_maxComb_sp_10meanEdgesPerGene.tsv.layout.json')
# Omitting edges, using canvas, and fast layout default because the network is large
# SEJveChjaGlsZHJlbj0oVkJveChjaGlsZHJlbj0oRHJvcGRvd24oaW5kZXg9MSwgbGF5b3V0PUxheW91dCh3aWR0aD11JzE1MHB4JyksIG9wdGlvbnM9KCdTVkcnLCAnY2FudmFzJyksIHZhbHXigKY=

# %%
###Build object to explore GRN network graphically and generate heatmap of TFs by condition
L=LExpression.LinkedExpressionNetwork()
L.show()
L.load_network(directory+'/'+netPath+'/'+networkFile)
L.load_heatmap(directory +'/'+netPath+'/'+expressionFile)
N = L.network
N.set_title(netTitle)
L.expression.transform_dropdown.value = 'Z score'
L.expression.apply_transform()
# Out:
# VkJveChjaGlsZHJlbj0oSEJveChjaGlsZHJlbj0oVkJveChjaGlsZHJlbj0oRHJvcGRvd24obGF5b3V0PUxheW91dCh3aWR0aD11JzE1MHB4JyksIG9wdGlvbnM9KCdTVkcnLCAnY2FudmFzJynigKY=
# ('Reading network', './Epi/prior_lung_epithelial_macaque_b_bias50_maxComb_sp_10meanEdgesPerGene.tsv')
# ('Loading saved layout', './Epi/prior_lung_epithelial_macaque_b_bias50_maxComb_sp_10meanEdgesPerGene.tsv.layout.json')
# Omitting edges, using canvas, and fast layout default because the network is large
